# %%
import pandas as pd
df_uni = pd.read_csv(r'qs-world-university-rankings-2017-to-2022-V2.csv')
df_uni.head()
# Out:
#                                      university  year rank_display  score  \
# 0  Massachusetts Institute of Technology (MIT)   2017            1  100.0
# 1                           Stanford University  2017            2   98.7
# 2                            Harvard University  2017            3   98.3
# 3                       University of Cambridge  2017            4   97.2
# 4  California Institute of Technology (Caltech)  2017            5   96.9
#
#                                                 link         country  \
# 0  https://www.topuniversities.com/universities/m...   United States
# 1  https://www.topuniversities.com/universities/s...   United States
# 2  https://www.topuniversities.com/universities/h...   United States
# 3  https://www.topuniversities.com/universities/u...  United Kingdom
# 4  https://www.topuniversities.com/universities/c...   United States
#
#         city         region  \
# 0  Cambridge  North America
# 1   Stanford  North America
# 2  Cambridge  North America
# 3  Cambridge         Europe
# 4   Pasadena  North America
#
#                                                 logo     type research_output  \
# 0  https://www.topuniversities.com/sites/default/...  Private       Very High
# 1  https://www.topuniversities.com/sites/default/...  Private       Very High
# 2  https://www.topuniversities.com/sites/default/...  Private       Very High
# 3  https://www.topuniversities.com/sites/default/...   Public       Very high
# 4  https://www.topuniversities.com/sites/default/...  Private       Very High
#
#    student_faculty_ratio international_students size faculty_count
# 0                    4.0                  3,730    M         3,065
# 1                    3.0                  3,879    L         4,725
# 2                    5.0                  5,877    L         4,646
# 3                    4.0                  7,925    L         5,800
# 4                    2.0                    692    S           968

# %%
df_uni.columns
# Out:
# Index(['university', 'year', 'rank_display', 'score', 'link', 'country',
#        'city', 'region', 'logo', 'type', 'research_output',
#        'student_faculty_ratio', 'international_students', 'size',
#        'faculty_count'],
#       dtype='object')

# %%
# Check if 'link' and 'logo' columns exist in the dataframe
if 'link' in df_uni.columns and 'logo' in df_uni.columns:
    # Drop 'link' and 'logo' columns
    df_uni = df_uni.drop(['link', 'logo'], axis=1)

df_uni
# Out:
#                                         university  year rank_display  score  \
# 0     Massachusetts Institute of Technology (MIT)   2017            1  100.0
# 1                              Stanford University  2017            2   98.7
# 2                               Harvard University  2017            3   98.3
# 3                          University of Cambridge  2017            4   97.2
# 4     California Institute of Technology (Caltech)  2017            5   96.9
# ...                                            ...   ...          ...    ...
# 6477                           Université de Tunis  2022         1201    NaN
# 6478                  Université de Tunis El Manar  2022         1201    NaN
# 6479                            Yarmouk University  2022         1201    NaN
# 6480                   Yildiz Technical University  2022         1201    NaN
# 6481                            Zagazig University  2022         1201    NaN
#
#              country       city         region     type research_output  \
# 0      United States  Cambridge  North America  Private       Very High
# 1      United States   Stanford  North America  Private       Very High
# 2      United States  Cambridge  North America  Private       Very High
# 3     United Kingdom  Cambridge         Europe   Public       Very high
# 4      United States   Pasadena  North America  Private       Very High
# ...              ...        ...            ...      ...             ...
# 6477         Tunisia      Tunis         Africa   Public            High
# 6478         Tunisia      Tunis         Africa   Public       Very High
# 6479          Jordan      Irbid           Asia   Public          Medium
# 6480          Turkey   Istanbul           Asia   Public            High
# 6481           Egypt    Zagazig         Africa   Public            High
#
#       student_faculty_ratio international_students size faculty_count
# 0                       4.0                  3,730    M         3,065
# 1                       3.0                  3,879    L         4,725
# 2                       5.0                  5,877    L         4,646
# 3                       4.0                  7,925    L         5,800
# 4                       2.0                    692    S           968
# ...                     ...                    ...  ...           ...
# 6477                   17.0                     57    L         1,174
# 6478                    8.0                    585    L         3,504
# 6479                   31.0                  2,826   XL         1,113
# 6480                   20.0                  2,394   XL         1,688
# 6481                   26.0                  2,300   XL         5,871
#
# [6482 rows x 13 columns]

# %%
df_uni.dtypes
# Out:
# university                 object
# year                        int64
# rank_display               object
# score                     float64
# country                    object
# city                       object
# region                     object
# type                       object
# research_output            object
# student_faculty_ratio     float64
# international_students     object
# size                       object
# faculty_count              object
# dtype: object

# %%
df_uni['rank_display'] = pd.to_numeric(df_uni['rank_display'], errors='coerce')
df_uni['score'] = pd.to_numeric(df_uni['score'], errors='coerce')
df_uni['international_students'] = pd.to_numeric(df_uni['international_students'], errors='coerce')

# %%
df_uni
# Out:
#                                         university  year  rank_display  score  \
# 0     Massachusetts Institute of Technology (MIT)   2017           1.0  100.0
# 1                              Stanford University  2017           2.0   98.7
# 2                               Harvard University  2017           3.0   98.3
# 3                          University of Cambridge  2017           4.0   97.2
# 4     California Institute of Technology (Caltech)  2017           5.0   96.9
# ...                                            ...   ...           ...    ...
# 6477                           Université de Tunis  2022        1201.0    NaN
# 6478                  Université de Tunis El Manar  2022        1201.0    NaN
# 6479                            Yarmouk University  2022        1201.0    NaN
# 6480                   Yildiz Technical University  2022        1201.0    NaN
# 6481                            Zagazig University  2022        1201.0    NaN
#
#              country       city         region     type research_output  \
# 0      United States  Cambridge  North America  Private       Very High
# 1      United States   Stanford  North America  Private       Very High
# 2      United States  Cambridge  North America  Private       Very High
# 3     United Kingdom  Cambridge         Europe   Public       Very high
# 4      United States   Pasadena  North America  Private       Very High
# ...              ...        ...            ...      ...             ...
# 6477         Tunisia      Tunis         Africa   Public            High
# 6478         Tunisia      Tunis         Africa   Public       Very High
# 6479          Jordan      Irbid           Asia   Public          Medium
# 6480          Turkey   Istanbul           Asia   Public            High
# 6481           Egypt    Zagazig         Africa   Public            High
#
#       student_faculty_ratio international_students size faculty_count  \
# 0                       4.0                  3,730    M         3,065
# 1                       3.0                  3,879    L         4,725
# 2                       5.0                  5,877    L         4,646
# 3                       4.0                  7,925    L         5,800
# 4                       2.0                    692    S           968
# ...                     ...                    ...  ...           ...
# 6477                   17.0                     57    L         1,174
# 6478                    8.0                    585    L         3,504
# 6479                   31.0                  2,826   XL         1,113
# 6480                   20.0                  2,394   XL         1,688
# 6481                   26.0                  2,300   XL         5,871
#
#       iinternational_students
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                       692.0
# ...                       ...
# 6477                     57.0
# 6478                    585.0
# 6479                      NaN
# 6480                      NaN
# 6481                      NaN
#
# [6482 rows x 14 columns]

# %%
# drop rows when rank_display is greater than 100 
df_rank_100 = df_uni[df_uni['rank_display'] <= 100]

# %%
# dataset from 2017 - 2022 with rank_display <= 100

df_rank_100
# Out:
#                                          university  year  rank_display  \
# 0      Massachusetts Institute of Technology (MIT)   2017           1.0
# 1                               Stanford University  2017           2.0
# 2                                Harvard University  2017           3.0
# 3                           University of Cambridge  2017           4.0
# 4      California Institute of Technology (Caltech)  2017           5.0
# ...                                             ...   ...           ...
# 5278                  Pennsylvania State University  2022          96.0
# 5279                 Sungkyunkwan University (SKKU)  2022          97.0
# 5280  University of Science and Technology of China  2022          98.0
# 5281                Technical University of Denmark  2022          99.0
# 5282      University of North Carolina, Chapel Hill  2022         100.0
#
#       score           country             city         region     type  \
# 0     100.0     United States        Cambridge  North America  Private
# 1      98.7     United States         Stanford  North America  Private
# 2      98.3     United States        Cambridge  North America  Private
# 3      97.2    United Kingdom        Cambridge         Europe   Public
# 4      96.9     United States         Pasadena  North America  Private
# ...     ...               ...              ...            ...      ...
# 5278   61.5     United States  University Park  North America   Public
# 5279   60.5       South Korea            Suwon           Asia  Private
# 5280   60.1  China (Mainland)            Hefei           Asia   Public
# 5281   59.9           Denmark   Kongens Lyngby         Europe   Public
# 5282   59.6     United States      Chapel Hill  North America   Public
#
#      research_output  student_faculty_ratio international_students size  \
# 0          Very High                    4.0                  3,730    M
# 1          Very High                    3.0                  3,879    L
# 2          Very High                    5.0                  5,877    L
# 3          Very high                    4.0                  7,925    L
# 4          Very High                    2.0                    692    S
# ...              ...                    ...                    ...  ...
# 5278       Very High                   11.0                  6,943   XL
# 5279       Very High                    7.0                  3,821    L
# 5280       Very High                    7.0                  1,019    L
# 5281       Very High                    4.0                  2,495    M
# 5282       Very High                    7.0                  2,749   XL
#
#      faculty_count  iinternational_students
# 0            3,065                      NaN
# 1            4,725                      NaN
# 2            4,646                      NaN
# 3            5,800                      NaN
# 4              968                    692.0
# ...            ...                      ...
# 5278         4,207                      NaN
# 5279         3,313                      NaN
# 5280         2,708                      NaN
# 5281         2,219                      NaN
# 5282         4,646                      NaN
#
# [605 rows x 14 columns]

# %%
df_rank_100.groupby('country').agg({'rank_display': 'count', 'year':}).sort_values(by='rank_display', ascending=False)

# %%
# make a new dataframe filter year = 2017  our main dataset
df_2017 = df_rank_100[df_rank_100['year'] == 2017]
df_2017
# Out:
#                                            university  year  rank_display  \
# 0        Massachusetts Institute of Technology (MIT)   2017           1.0
# 1                                 Stanford University  2017           2.0
# 2                                  Harvard University  2017           3.0
# 3                             University of Cambridge  2017           4.0
# 4        California Institute of Technology (Caltech)  2017           5.0
# ..                                                ...   ...           ...
# 96                 KTH Royal Institute of Technology   2017          97.0
# 97                                 Uppsala University  2017          98.0
# 98                                   Korea University  2017          98.0
# 99   Trinity College Dublin, The University of Dublin  2017          98.0
# 100            KIT, Karlsruhe Institute of Technology  2017          98.0
#
#      score         country       city         region     type research_output  \
# 0    100.0   United States  Cambridge  North America  Private       Very High
# 1     98.7   United States   Stanford  North America  Private       Very High
# 2     98.3   United States  Cambridge  North America  Private       Very High
# 3     97.2  United Kingdom  Cambridge         Europe   Public       Very high
# 4     96.9   United States   Pasadena  North America  Private       Very High
# ..     ...             ...        ...            ...      ...             ...
# 96    63.1          Sweden  Stockholm         Europe   Public       Very High
# 97    62.8          Sweden    Uppsala         Europe   Public       Very High
# 98    62.8     South Korea      Seoul           Asia  Private       Very High
# 99    62.8         Ireland     Dublin         Europe   Public       Very High
# 100   62.8         Germany  Karlsruhe         Europe   Public       Very High
#
#      student_faculty_ratio international_students size faculty_count  \
# 0                      4.0                  3,730    M         3,065
# 1                      3.0                  3,879    L         4,725
# 2                      5.0                  5,877    L         4,646
# 3                      4.0                  7,925    L         5,800
# 4                      2.0                    692    S           968
# ..                     ...                    ...  ...           ...
# 96                     8.0                  3,057    L         3,600
# 97                    10.0                  8,401    L         2,843
# 98                     6.0                  3,325    L         4,026
# 99                    12.0                  5,593    L         1,383
# 100                   10.0                  5,030    L         2,080
#
#      iinternational_students
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                      692.0
# ..                       ...
# 96                       NaN
# 97                       NaN
# 98                       NaN
# 99                       NaN
# 100                      NaN
#
# [101 rows x 14 columns]

# %%
df_2017.groupby('country').agg({'rank_display': 'count'}).sort_values(by='rank_display', ascending=False)
# Out:
#                   rank_display
# country
# United States               32
# United Kingdom              18
# Australia                    6
# Japan                        5
# South Korea                  4
# Canada                       4
# China (Mainland)             4
# Switzerland                  4
# Germany                      4
# Hong Kong SAR                4
# Sweden                       3
# France                       2
# Netherlands                  2
# Singapore                    2
# Taiwan                       1
# Argentina                    1
# New Zealand                  1
# Finland                      1
# Denmark                      1
# Belgium                      1
# Ireland                      1
